# %%
import pandas as pd

# %%
df = pd.read_csv('dog_lic.csv')

# %%
df['Borough'].unique()
# Out:
# array(['Brooklyn', 'Bronx', 'Manhattan', 'Staten Island', 'Queens',
#        'BROOKLYN', 'STATEN IS', 'QUEENS', 'BRONX', 'MANHATTAN',
#        'New York', 'New york', 'ASTORIA', 'New York  ', 'Brooklyn ',
#        'Bronx ', 'NEW YORK CITY', 'bronx', 'New York ', 'Manhattan ',
#        'Flushing', 'elmhurst', 'The Villages', 'Rockaway Park',
#        'Fresh meadows', 'Corona', 'Elmhurst', 'Astoria', 'fresh meadows',
#        'NEW YORK', 'College Point', 'new york', 'MIDDLE VILG', 'Quens',
#        'Jersey City', 'San Francisco', 'Richmond Hill', 'East Elmhurst',
#        'Ridgewood', 'bronxville', 'Hoboken', 'NYC', 'Floral Park',
#        'Elmhurst ', 'NY', 'Middle Village', 'Potomac', 'Ozone Park', nan,
#        'Glendale', 'Long Island City', 'oakland gardens', 'ozone park',
#        'Staten Island, NY', 'Wappingers Falls, NY', 'Woodside', 'B',
#        'Glen Oaks', 'Woodside NY.', 'Kew Gardens', 'staten island',
#        'BELLE HARBOR', 'Jackson heights ', 'Lynbrook', 'ARVERNE',
# ...

# %%
df.head(10)
# Out:
#    RowNumber AnimalName AnimalGender        AnimalBirthMonth BreedName  \
# 0       1753    SHADOW             M  01/01/2000 12:00:00 AM    Beagle
# 1       2415      ROCCO            M  10/01/2011 12:00:00 AM     Boxer
# 2       3328      LUIGI            M  09/01/2005 12:00:00 AM   Maltese
# 3       7537    PETUNIA            F  08/01/2013 12:00:00 AM       Pug
# 4       8487      ROMEO            M  10/01/2008 12:00:00 AM   Maltese
# 5      10503    BRANDY             M  01/01/2004 12:00:00 AM   Unknown
# 6      11682        SAM            M  05/01/2011 12:00:00 AM       Pug
# 7      12307       MAY             F  05/01/2004 12:00:00 AM   Unknown
# 8      12652       RUBY            F  04/01/2010 12:00:00 AM     Boxer
# 9      13839        LEO            M  01/01/2014 12:00:00 AM    Beagle
#
#          Borough  ZipCode  CommunityDistrict  CensusTract2010   NTA  \
# 0       Brooklyn  11236.0              318.0           1014.0  BK50
# ...

# %%
df.describe()
# Out:
#            RowNumber        ZipCode  CommunityDistrict  CensusTract2010  \
# count  121949.000000  121948.000000      118612.000000    118612.000000
# mean    61135.411483   10678.399424         265.208689      7340.266997
# std     35319.806867     917.181379         137.623473     21419.097363
# min         1.000000     121.000000         101.000000         1.000000
# 25%     30491.000000   10029.000000         108.000000       126.000000
# 50%     61250.000000   10465.000000         302.000000       251.000000
# 75%     91738.000000   11228.000000         403.000000       912.000000
# max    122229.000000   94608.000000         595.000000    157903.000000
#
#        CityCouncilDistrict  CongressionalDistrict  StateSenatorialDistrict
# count        118612.000000          118612.000000            118612.000000
# mean             22.827749              10.264939                23.537290
# std              16.638500               2.868837                 6.693253
# ...

# %%
name_row = df['AnimalName']
name_row.value_counts()
# Out:
# UNKNOWN              2467
# NAME NOT PROVIDED    1764
# BELLA                1008
# MAX                  1001
# CHARLIE               750
# LOLA                  686
# ROCKY                 668
# COCO                  642
# LUCY                  581
# BUDDY                 559
# LUCKY                 551
# DAISY                 507
# LUNA                  464
# BAILEY                429
# PRINCESS              428
# CHLOE                 419
# TEDDY                 417
# TOBY                  415
# MOLLY                 411
# BELLA                 351
# JACK                  351
# MILO                  349
# SOPHIE                341
# OLIVER                334
# PENNY                 334
# COOPER                319
# LILY                  315
# COCO                  301
# STELLA                299
# LEO                   293
#                      ...
# LUMPKIN                 1
# MOXI                    1
# TRIXIEBELLE             1
# SHIVER                  1
# ...
